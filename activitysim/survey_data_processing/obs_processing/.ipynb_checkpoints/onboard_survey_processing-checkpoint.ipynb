# %%
import pandas as pd
pd.set_option("display.max_columns",250)
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import yaml as yaml
# import openpyxl
import random

sns.set()
# import openmatrix as omx
# import geopandas
# import pyproj
# import re
# import xlrd
from IPython.display import display, HTML

# %%
def add_percentage_to_crosstab(ct):
    total_counts = ct['All'][:-1].sum()
    ct['Percent'] = ct.apply(lambda row: round(100 * row['All'] / total_counts, 2), axis=1)
    ct.loc['Percent'] = ct.apply(lambda col: round(100 * col['All'] / total_counts, 2), axis=0)
    ct.loc['Percent', 'Percent'] = pd.NA
    return ct

# %%
def make_percentage_bar_plot(variable, title, xlabel, xlabel_rotation):
    grouped_df = obs_df.groupby(variable)["unlinked_weight_scaled"].agg(sum)
    total_weight = grouped_df.sum()
    grouped_df["percent"] = grouped_df/total_weight*100
    plt.figure(figsize=(10,7))
    grouped_df["percent"].plot.bar()
    plt.xlabel(xlabel, fontsize=16)
    plt.xticks(rotation=xlabel_rotation)
    plt.ylabel("Weighted Percent", fontsize=16)
    plt.title(title, fontsize=16)
    plt.show()
    
def make_percentage_bar_plot_cta(variable, title, xlabel, xlabel_rotation):
    grouped_df = obs_df.groupby(variable)["unlinked_weight_scaled"].agg(sum)
    total_weight = grouped_df.sum()
    grouped_df["percent"] = grouped_df/total_weight*100
    plt.figure(figsize=(10,7))
    grouped_df["percent"].plot.bar()
    plt.xlabel(xlabel, fontsize=16)
    plt.xticks(rotation=xlabel_rotation)
    plt.ylabel("Weighted Percent", fontsize=16)
    plt.title(title, fontsize=16)
    plt.show()
    
def make_percentage_bar_plot_metra(variable, title, xlabel, xlabel_rotation):
    grouped_df = metra_df.groupby(variable)["unlinked_weight_scaled"].agg(sum)
    total_weight = grouped_df.sum()
    grouped_df["percent"] = grouped_df/total_weight*100
    plt.figure(figsize=(10,7))
    grouped_df["percent"].plot.bar()
    plt.xlabel(xlabel, fontsize=16)
    plt.xticks(rotation=xlabel_rotation)
    plt.ylabel("Weighted Percent", fontsize=16)
    plt.title(title, fontsize=16)
    plt.show()

# %%
with open(r'E:/Projects/Clients/MetCouncilASIM/tasks/survey_data_processing/metc_inputs.yml') as file:
    settings = yaml.load(file)

obs_path  = os.path.join(settings['obs_dir'], 'TravelBehaviorInventory2016TransitOnBoardSurvey.csv')

obs_df = pd.read_csv(obs_path)

output_path = r"output"
# Out:
# C:\Users\leah.flake\.conda\envs\mcasim\lib\site-packages\ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#
# C:\Users\leah.flake\.conda\envs\mcasim\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,6,7,8,17,20,21,22,54,57,60,61,62,104) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
obs_df
# Out:
#             ID                    DATE ROUTE_SURVEYED_CODE  \
# 0            1  Monday, April 11, 2016           MMTBLUE01
# 1            2  Monday, April 11, 2016           MMTBLUE01
# 2            3  Monday, April 11, 2016              MMT500
# 3            4  Monday, April 11, 2016           MMTBLUE00
# 4            5  Monday, April 11, 2016           MMTBLUE00
# ...        ...                     ...                 ...
# 30600  DM90110            Dummy Record           MMTBLUE01
# 30601  DM90111            Dummy Record           MMTBLUE01
# 30602  DM90112            Dummy Record           MMTBLUE01
# 30603  DM90113            Dummy Record           MMTBLUE01
# 30604  DM90114            Dummy Record           MMTBLUE01
#
#                                           ROUTE_SURVEYED  \
# 0                              BLUE METRO Blue Line [SB]
# 1                              BLUE METRO Blue Line [SB]
# 2      5 Brklyn Center - Fremont - 26th Av - Chicago ...
# 3                              BLUE METRO Blue Line [NB]
# 4                              BLUE METRO Blue Line [NB]
# ...                                                  ...
# 30600                          BLUE METRO Blue Line [SB]
# 30601                          BLUE METRO Blue Line [SB]
# 30602                          BLUE METRO Blue Line [SB]
# 30603                          BLUE METRO Blue Line [SB]
# 30604                          BLUE METRO Blue Line [SB]
#
#       HOME_OR_HOTEL_ADDR_CITY HOME_OR_HOTEL_ADDR_STATE HOME_OR_HOTEL_ADDR_ZIP  \
# 0                 Minneapolis                Minnesota                  55417
# 1                 Minneapolis                Minnesota                  55404
# 2                 Minneapolis                Minnesota                  55411
# 3                       Eagan                Minnesota                  55123
# 4                     St Paul                Minnesota                  55105
# ...                       ...                      ...                    ...
# 30600                     NaN                      NaN                    NaN
# 30601                     NaN                      NaN                    NaN
# 30602                     NaN                      NaN                    NaN
# 30603                     NaN                      NaN                    NaN
# 30604                     NaN                      NaN                    NaN
#
#       HOME_OR_HOTEL_ADDR_LAT_100M HOME_OR_HOTEL_ADDR_LON_100M  \
# 0                          44.902                     -93.223
# 1                          44.955                     -93.246
# 2                          45.010                     -93.301
# 3                          44.830                     -93.153
# 4                          44.940                     -93.144
# ...                           ...                         ...
# 30600                         NaN                         NaN
# 30601                         NaN                         NaN
# 30602                         NaN                         NaN
# 30603                         NaN                         NaN
# 30604                         NaN                         NaN
#
#                     BOARDING_LOCATION  BOARDING_STOPID  BOARDING_LAT  \
# 0      Warehouse Hennepin Ave Station          56336.0     44.980003
# 1                     38th St Station          51414.0     44.934613
# 2           Chicago Ave S & 25th St E            808.0     44.957239
# 3                 MOA Transit Station          51405.0     44.854287
# 4           VA Medical Center Station          51432.0     44.902984
# ...                               ...              ...           ...
# 30600                             NaN              NaN           NaN
# 30601                             NaN              NaN           NaN
# 30602                             NaN              NaN           NaN
# 30603                             NaN              NaN           NaN
# 30604                             NaN              NaN           NaN
#
#        BOARDING_LON  TRANSFERS_FROM_CODE TRANSFERS_FROM  \
# 0        -93.273144                  1.0        (1) One
# 1        -93.229421                  1.0        (1) One
# 2        -93.262505                  0.0       (0) None
# 3        -93.238861                  1.0        (1) One
# 4        -93.202324                  0.0       (0) None
# ...             ...                  ...            ...
# 30600           NaN                  NaN            NaN
# 30601           NaN                  NaN            NaN
# 30602           NaN                  NaN            NaN
# 30603           NaN                  NaN            NaN
# 30604           NaN                  NaN            NaN
#
#       TRANSFERS_FROM_FIRST_CODE  \
# 0                          MMT6
# 1                         MMT22
# 2                           NaN
# 3                        MVTRED
# 4                           NaN
# ...                         ...
# 30600                       NaN
# 30601                       NaN
# 30602                       NaN
# 30603                       NaN
# 30604                       NaN
#
#                                     TRANSFERS_FROM_FIRST  \
# 0      6 U of M - Hennepin - Xerxes - France - Southd...
# 1      22 Brklyn Ctr - Lyndale Av N - Cedar - 28th Av...
# 2                                                    NaN
# 3        RED METRO Red Line [ Minnesota Valley Transit ]
# 4                                                    NaN
# ...                                                  ...
# 30600                                                NaN
# 30601                                                NaN
# 30602                                                NaN
# 30603                                                NaN
# 30604                                                NaN
#
#       TRANSFERS_FROM_FIRST_OTHER TRANSFERS_FROM_SECOND_CODE  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 30600                        NaN                        NaN
# 30601                        NaN                        NaN
# 30602                        NaN                        NaN
# 30603                        NaN                        NaN
# 30604                        NaN                        NaN
#
#       TRANSFERS_FROM_SECOND TRANSFERS_FROM_SECOND_OTHER  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 30600                   NaN                         NaN
# 30601                   NaN                         NaN
# 30602                   NaN                         NaN
# 30603                   NaN                         NaN
# 30604                   NaN                         NaN
#
#       TRANSFERS_FROM_THIRD_CODE TRANSFERS_FROM_THIRD  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# ...                         ...                  ...
# 30600                       NaN                  NaN
# 30601                       NaN                  NaN
# 30602                       NaN                  NaN
# 30603                       NaN                  NaN
# 30604                       NaN                  NaN
#
#        TRANSFERS_FROM_THIRD_OTHER  TRANSFERS_FROM_FOURTH_CODE  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 30600                         NaN                         NaN
# 30601                         NaN                         NaN
# 30602                         NaN                         NaN
# 30603                         NaN                         NaN
# 30604                         NaN                         NaN
#
#        TRANSFERS_FROM_FOURTH  ORIGIN_PLACE_TYPE_CODE  \
# 0                        NaN                     8.0
# 1                        NaN                     1.0
# 2                        NaN                     2.0
# 3                        NaN                     1.0
# 4                        NaN                     5.0
# ...                      ...                     ...
# 30600                    NaN                     NaN
# 30601                    NaN                     NaN
# 30602                    NaN                     NaN
# 30603                    NaN                     NaN
# 30604                    NaN                     NaN
#
#                                      ORIGIN_PLACE_TYPE  ORIGIN_CITY  \
# 0      Social Visit / Community / Religious / Personal  Minneapolis
# 1                                            Your HOME  Minneapolis
# 2                                                 Work  Minneapolis
# 3                                            Your HOME        Eagan
# 4                Doctor / Clinic / Hospital (non-work)  Minneapolis
# ...                                                ...          ...
# 30600                                              NaN          NaN
# 30601                                              NaN          NaN
# 30602                                              NaN          NaN
# 30603                                              NaN          NaN
# 30604                                              NaN          NaN
#
#       ORIGIN_STATE  ORIGIN_ZIP  ORIGIN_LAT_100M  ORIGIN_LON_100M  \
# 0        Minnesota     55408.0           44.948          -93.299
# 1        Minnesota     55404.0           44.955          -93.246
# 2        Minnesota     55404.0           44.957          -93.258
# 3        Minnesota     55123.0           44.830          -93.153
# 4        Minnesota     55417.0           44.901          -93.205
# ...            ...         ...              ...              ...
# 30600          NaN         NaN              NaN              NaN
# 30601          NaN         NaN              NaN              NaN
# 30602          NaN         NaN              NaN              NaN
# 30603          NaN         NaN              NaN              NaN
# 30604          NaN         NaN              NaN              NaN
#
#        ACCESS_MODE_CODE             ACCESS_MODE  \
# 0                   1.0                    Walk
# 1                   1.0                    Walk
# 2                   1.0                    Walk
# 3                   5.0  Drove alone and parked
# 4                   1.0                    Walk
# ...                 ...                     ...
# 30600               NaN                     NaN
# 30601               NaN                     NaN
# 30602               NaN                     NaN
# 30603               NaN                     NaN
# 30604               NaN                     NaN
#
#        VEHICLE_ACCESS_PARK_YN_PNR_CODE VEHICLE_ACCESS_PARK_YN_PNR  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  1.0                        Yes
# 4                                  NaN                        NaN
# ...                                ...                        ...
# 30600                              NaN                        NaN
# 30601                              NaN                        NaN
# 30602                              NaN                        NaN
# 30603                              NaN                        NaN
# 30604                              NaN                        NaN
#
#         VEHICLE_ACCESS_PARK_PNR_CODE  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3      PNR_1016_44.812084_-93.217887
# 4                                NaN
# ...                              ...
# 30600                            NaN
# 30601                            NaN
# 30602                            NaN
# 30603                            NaN
# 30604                            NaN
#
#                             VEHICLE_ACCESS_PARK_PNR  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3      Cedar Grove Transit Station @ 4035 Nicols Rd
# 4                                               NaN
# ...                                             ...
# 30600                                           NaN
# 30601                                           NaN
# 30602                                           NaN
# 30603                                           NaN
# 30604                                           NaN
#
#        VEHICLE_ACCESS_PARK_PNR_OTHER VEHICLE_ACCESS_DROPOFF  \
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    NaN
# 3                                NaN         4035 Nicols Rd
# 4                                NaN                    NaN
# ...                              ...                    ...
# 30600                            NaN                    NaN
# 30601                            NaN                    NaN
# 30602                            NaN                    NaN
# 30603                            NaN                    NaN
# 30604                            NaN                    NaN
#
#       VEHICLE_ACCESS_DROPOFF_CITY VEHICLE_ACCESS_DROPOFF_STATE  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                           Eagan                    Minnesota
# 4                             NaN                          NaN
# ...                           ...                          ...
# 30600                         NaN                          NaN
# 30601                         NaN                          NaN
# 30602                         NaN                          NaN
# 30603                         NaN                          NaN
# 30604                         NaN                          NaN
#
#        VEHICLE_ACCESS_DROPOFF_ZIP  VEHICLE_ACCESS_DROPOFF_LAT  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                         55122.0                   44.812084
# 4                             NaN                         NaN
# ...                           ...                         ...
# 30600                         NaN                         NaN
# 30601                         NaN                         NaN
# 30602                         NaN                         NaN
# 30603                         NaN                         NaN
# 30604                         NaN                         NaN
#
#        VEHICLE_ACCESS_DROPOFF_LON               ALIGHTING_LOCATION  \
# 0                             NaN                  46th St Station
# 1                             NaN              MOA Transit Station
# 2                             NaN       Emerson Ave N & 30th Ave N
# 3                      -93.217887  Target Field Station Platform 1
# 4                             NaN   Warehouse Hennepin Ave Station
# ...                           ...                              ...
# 30600                         NaN                              NaN
# 30601                         NaN                              NaN
# 30602                         NaN                              NaN
# 30603                         NaN                              NaN
# 30604                         NaN                              NaN
#
#        ALIGHTING_STOPID  ALIGHTING_LAT  ALIGHTING_LON  TRANSFERS_TO_CODE  \
# 0               51415.0      44.920808     -93.220028                1.0
# 1               51405.0      44.854287     -93.238861                2.0
# 2                8934.0      45.011203     -93.294272                0.0
# 3               56333.0      44.983101     -93.277355                0.0
# 4               56332.0      44.980159     -93.273159                0.0
# ...                 ...            ...            ...                ...
# 30600               NaN            NaN            NaN                NaN
# 30601               NaN            NaN            NaN                NaN
# 30602               NaN            NaN            NaN                NaN
# 30603               NaN            NaN            NaN                NaN
# 30604               NaN            NaN            NaN                NaN
#
#       TRANSFERS_TO TRANSFERS_TO_FIRST_CODE  \
# 0          (1) One                    MMT7
# 1          (2) Two                  MVTRED
# 2         (0) None                     NaN
# 3         (0) None                     NaN
# 4         (0) None                     NaN
# ...            ...                     ...
# 30600          NaN                     NaN
# 30601          NaN                     NaN
# 30602          NaN                     NaN
# 30603          NaN                     NaN
# 30604          NaN                     NaN
#
#                                       TRANSFERS_TO_FIRST  \
# 0      7 Plymouth - 27Av - Midtown - 46St LRT - 34Av ...
# 1        RED METRO Red Line [ Minnesota Valley Transit ]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30600                                                NaN
# 30601                                                NaN
# 30602                                                NaN
# 30603                                                NaN
# 30604                                                NaN
#
#       TRANSFERS_TO_FIRST_OTHER TRANSFERS_TO_SECOND_CODE  \
# 0                          NaN                      NaN
# 1                          NaN                   MVT491
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 30600                      NaN                      NaN
# 30601                      NaN                      NaN
# 30602                      NaN                      NaN
# 30603                      NaN                      NaN
# 30604                      NaN                      NaN
#
#                                      TRANSFERS_TO_SECOND  \
# 0                                                    NaN
# 1      491 Scott County-Minneapolis Rev Commute [ Min...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30600                                                NaN
# 30601                                                NaN
# 30602                                                NaN
# 30603                                                NaN
# 30604                                                NaN
#
#       TRANSFERS_TO_SECOND_OTHER TRANSFERS_TO_THIRD_CODE TRANSFERS_TO_THIRD  \
# 0                           NaN                     NaN                NaN
# 1                           NaN                     NaN                NaN
# 2                           NaN                     NaN                NaN
# 3                           NaN                     NaN                NaN
# 4                           NaN                     NaN                NaN
# ...                         ...                     ...                ...
# 30600                       NaN                     NaN                NaN
# 30601                       NaN                     NaN                NaN
# 30602                       NaN                     NaN                NaN
# 30603                       NaN                     NaN                NaN
# 30604                       NaN                     NaN                NaN
#
#       TRANSFERS_TO_THIRD_OTHER TRANSFERS_TO_FOURTH_CODE TRANSFERS_TO_FOURTH  \
# 0                          NaN                      NaN                 NaN
# 1                          NaN                      NaN                 NaN
# 2                          NaN                      NaN                 NaN
# 3                          NaN                      NaN                 NaN
# 4                          NaN                      NaN                 NaN
# ...                        ...                      ...                 ...
# 30600                      NaN                      NaN                 NaN
# 30601                      NaN                      NaN                 NaN
# 30602                      NaN                      NaN                 NaN
# 30603                      NaN                      NaN                 NaN
# 30604                      NaN                      NaN                 NaN
#
#        DESTIN_PLACE_TYPE_CODE  \
# 0                         8.0
# 1                         7.0
# 2                         1.0
# 3                         7.0
# 4                         8.0
# ...                       ...
# 30600                     NaN
# 30601                     NaN
# 30602                     NaN
# 30603                     NaN
# 30604                     NaN
#
#                                      DESTIN_PLACE_TYPE DESTINATION_CITY  \
# 0      Social Visit / Community / Religious / Personal      Minneapolis
# 1                Recreation / Sightseeing / Restaurant       Prior Lake
# 2                                            Your HOME      Minneapolis
# 3                Recreation / Sightseeing / Restaurant      Minneapolis
# 4      Social Visit / Community / Religious / Personal      Minneapolis
# ...                                                ...              ...
# 30600                                              NaN              NaN
# 30601                                              NaN              NaN
# 30602                                              NaN              NaN
# 30603                                              NaN              NaN
# 30604                                              NaN              NaN
#
#       DESTINATION_STATE  DESTINATION_ZIP  DESTINATION_LAT_100M  \
# 0             Minnesota          55417.0                44.910
# 1             Minnesota          55372.0                44.730
# 2             Minnesota          55411.0                45.010
# 3             Minnesota          55403.0                44.979
# 4             Minnesota          55403.0                44.979
# ...                 ...              ...                   ...
# 30600               NaN              NaN                   NaN
# 30601               NaN              NaN                   NaN
# 30602               NaN              NaN                   NaN
# 30603               NaN              NaN                   NaN
# 30604               NaN              NaN                   NaN
#
#        DESTINATION_LON_100M  EGRESS_MODE_CODE EGRESS_MODE  \
# 0                   -93.223               1.0        Walk
# 1                   -93.473               1.0        Walk
# 2                   -93.301               1.0        Walk
# 3                   -93.276               1.0        Walk
# 4                   -93.276               1.0        Walk
# ...                     ...               ...         ...
# 30600                   NaN               NaN         NaN
# 30601                   NaN               NaN         NaN
# 30602                   NaN               NaN         NaN
# 30603                   NaN               NaN         NaN
# 30604                   NaN               NaN         NaN
#
#        VEHICLE_EGRESS_PARK_YN_PNR_CODE VEHICLE_EGRESS_PARK_YN_PNR  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
# ...                                ...                        ...
# 30600                              NaN                        NaN
# 30601                              NaN                        NaN
# 30602                              NaN                        NaN
# 30603                              NaN                        NaN
# 30604                              NaN                        NaN
#
#       VEHICLE_EGRESS_PARK_PNR_CODE VEHICLE_EGRESS_PARK_PNR  \
# 0                              NaN                     NaN
# 1                              NaN                     NaN
# 2                              NaN                     NaN
# 3                              NaN                     NaN
# 4                              NaN                     NaN
# ...                            ...                     ...
# 30600                          NaN                     NaN
# 30601                          NaN                     NaN
# 30602                          NaN                     NaN
# 30603                          NaN                     NaN
# 30604                          NaN                     NaN
#
#        VEHICLE_EGRESS_PARK_PNR_OTHER VEHICLE_EGRESS_DROPOFF  \
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    NaN
# 3                                NaN                    NaN
# 4                                NaN                    NaN
# ...                              ...                    ...
# 30600                            NaN                    NaN
# 30601                            NaN                    NaN
# 30602                            NaN                    NaN
# 30603                            NaN                    NaN
# 30604                            NaN                    NaN
#
#       VEHICLE_EGRESS_DROPOFF_CITY VEHICLE_EGRESS_DROPOFF_STATE  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 30600                         NaN                          NaN
# 30601                         NaN                          NaN
# 30602                         NaN                          NaN
# 30603                         NaN                          NaN
# 30604                         NaN                          NaN
#
#        VEHICLE_EGRESS_DROPOFF_ZIP  VEHICLE_EGRESS_DROPOFF_LAT  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 30600                         NaN                         NaN
# 30601                         NaN                         NaN
# 30602                         NaN                         NaN
# 30603                         NaN                         NaN
# 30604                         NaN                         NaN
#
#        VEHICLE_EGRESS_DROPOFF_LON  TIME_ON_CODE             TIME_ON  \
# 0                             NaN           8.0  12:00 pm - 1:00 pm
# 1                             NaN           8.0  12:00 pm - 1:00 pm
# 2                             NaN           9.0      1:00 - 2:00 pm
# 3                             NaN          12.0      4:00 - 5:00 pm
# 4                             NaN          12.0      4:00 - 5:00 pm
# ...                           ...           ...                 ...
# 30600                         NaN           NaN                 NaN
# 30601                         NaN           NaN                 NaN
# 30602                         NaN           NaN                 NaN
# 30603                         NaN           NaN                 NaN
# 30604                         NaN           NaN                 NaN
#
#       TIME_PERIOD  TRIP_IN_OPPOSITE_DIR_CODE TRIP_IN_OPPOSITE_DIR  \
# 0          Midday                        2.0                   No
# 1          Midday                        2.0                   No
# 2          Midday                        1.0                  Yes
# 3         PM Peak                        1.0                  Yes
# 4         PM Peak                        2.0                   No
# ...           ...                        ...                  ...
# 30600         NaN                        NaN                  NaN
# 30601         NaN                        NaN                  NaN
# 30602         NaN                        NaN                  NaN
# 30603         NaN                        NaN                  NaN
# 30604         NaN                        NaN                  NaN
#
#        OPP_DIR_TRIP_TIME_CODE OPP_DIR_TRIP_TIME  PAYMENT_METHOD_CODE  \
# 0                         NaN               NaN                  4.0
# 1                         NaN               NaN                  1.0
# 2                         5.0   9:00 - 10:00 am                  2.0
# 3                        17.0    8:00 - 9:00 pm                  2.0
# 4                         NaN               NaN                  4.0
# ...                       ...               ...                  ...
# 30600                     NaN               NaN                  NaN
# 30601                     NaN               NaN                  NaN
# 30602                     NaN               NaN                  NaN
# 30603                     NaN               NaN                  NaN
# 30604                     NaN               NaN                  NaN
#
#                                           PAYMENT_METHOD  FARE_TYPE_CODE  \
# 0      Qualified Free Ride Pass (Service Connected Ve...             2.0
# 1                                                   Cash             2.0
# 2                                     Go-To STORED VALUE             1.0
# 3                                     Go-To STORED VALUE             3.0
# 4      Qualified Free Ride Pass (Service Connected Ve...             2.0
# ...                                                  ...             ...
# 30600                                                NaN             NaN
# 30601                                                NaN             NaN
# 30602                                                NaN             NaN
# 30603                                                NaN             NaN
# 30604                                                NaN             NaN
#
#                    FARE_TYPE TRIP_PURPOSE_NO_OTHER_TRIP  \
# 0      Limited Mobility Pass                         No
# 1      Limited Mobility Pass                        Yes
# 2        Regular (age 13-64)                        Yes
# 3           Senior (Over 65)                        Yes
# 4      Limited Mobility Pass                         No
# ...                      ...                        ...
# 30600                    NaN                        NaN
# 30601                    NaN                        NaN
# 30602                    NaN                        NaN
# 30603                    NaN                        NaN
# 30604                    NaN                        NaN
#
#       TRIP_PURPOSE_BUY_A_MEAL_/_BEVERAGE TRIP_PURPOSE_GO_TO_WORK  \
# 0                                     No                      No
# 1                                     No                      No
# 2                                     No                      No
# 3                                     No                      No
# 4                                    Yes                      No
# ...                                  ...                     ...
# 30600                                NaN                     NaN
# 30601                                NaN                     NaN
# 30602                                NaN                     NaN
# 30603                                NaN                     NaN
# 30604                                NaN                     NaN
#
#       TRIP_PURPOSE_VISIT_FRIEND/RELATIVE_OR_ATTEND_RELIGIOUS/SOC_EVENT  \
# 0                                                     No
# 1                                                     No
# 2                                                     No
# 3                                                     No
# 4                                                     No
# ...                                                  ...
# 30600                                                NaN
# 30601                                                NaN
# 30602                                                NaN
# 30603                                                NaN
# 30604                                                NaN
#
#       TRIP_PURPOSE_GO_TO_SCHOOL TRIP_PURPOSE_GO_SHOPPING  \
# 0                            No                       No
# 1                            No                       No
# 2                            No                       No
# 3                            No                       No
# 4                            No                      Yes
# ...                         ...                      ...
# 30600                       NaN                      NaN
# 30601                       NaN                      NaN
# 30602                       NaN                      NaN
# 30603                       NaN                      NaN
# 30604                       NaN                      NaN
#
#       TRIP_PURPOSE_OTHER_ERRANDS TRIP_PURPOSE_OTHER  VISITOR_CODE VISITOR  \
# 0                            Yes                NaN           2.0      No
# 1                             No                NaN           2.0      No
# 2                             No                NaN           2.0      No
# 3                             No                NaN           2.0      No
# 4                             No                NaN           2.0      No
# ...                          ...                ...           ...     ...
# 30600                        NaN                NaN           NaN     NaN
# 30601                        NaN                NaN           NaN     NaN
# 30602                        NaN                NaN           NaN     NaN
# 30603                        NaN                NaN           NaN     NaN
# 30604                        NaN                NaN           NaN     NaN
#
#       COUNT_VH_HH_CODE COUNT_VH_HH  CAN_USE_VEH_TRIP_CODE CAN_USE_VEH_TRIP  \
# 0                    0    None (0)                    NaN              NaN
# 1                    0    None (0)                    NaN              NaN
# 2                    2     Two (2)                    2.0               No
# 3                    1     One (1)                    1.0              Yes
# 4                    1     One (1)                    1.0              Yes
# ...                ...         ...                    ...              ...
# 30600              NaN         NaN                    NaN              NaN
# 30601              NaN         NaN                    NaN              NaN
# 30602              NaN         NaN                    NaN              NaN
# 30603              NaN         NaN                    NaN              NaN
# 30604              NaN         NaN                    NaN              NaN
#
#        COUNT_MEMBER_HH_CODE COUNT_MEMBER_HH  COUNT_EMPLOYED_HH_CODE  \
# 0                       1.0         One (1)                     0.0
# 1                       1.0         One (1)                     0.0
# 2                       5.0        Five (5)                     2.0
# 3                       1.0         One (1)                     1.0
# 4                       1.0         One (1)                     0.0
# ...                     ...             ...                     ...
# 30600                   NaN             NaN                     NaN
# 30601                   NaN             NaN                     NaN
# 30602                   NaN             NaN                     NaN
# 30603                   NaN             NaN                     NaN
# 30604                   NaN             NaN                     NaN
#
#       COUNT_EMPLOYED_HH  STATUS_EMPLOYMENT_CODE  \
# 0              None (0)                     5.0
# 1              None (0)                     5.0
# 2               Two (2)                     1.0
# 3               One (1)                     2.0
# 4              None (0)                     4.0
# ...                 ...                     ...
# 30600               NaN                     NaN
# 30601               NaN                     NaN
# 30602               NaN                     NaN
# 30603               NaN                     NaN
# 30604               NaN                     NaN
#
#                                STATUS_EMPLOYMENT  STUDENT_STATUS_CODE  \
# 0                                        Retired                  1.0
# 1                                        Retired                  1.0
# 2                             Employed Full-time                  1.0
# 3                             Employed Part-time                  1.0
# 4      Not currently employed - not seeking work                  3.0
# ...                                          ...                  ...
# 30600                                        NaN                  NaN
# 30601                                        NaN                  NaN
# 30602                                        NaN                  NaN
# 30603                                        NaN                  NaN
# 30604                                        NaN                  NaN
#
#                                        STUDENT_STATUS  FARE_SUBSIDY_CODE  \
# 0                                       Not a student                NaN
# 1                                       Not a student                NaN
# 2                                       Not a student                3.0
# 3                                       Not a student                3.0
# 4      Yes - College / University / Community College                3.0
# ...                                               ...                ...
# 30600                                             NaN                NaN
# 30601                                             NaN                NaN
# 30602                                             NaN                NaN
# 30603                                             NaN                NaN
# 30604                                             NaN                NaN
#
#            FARE_SUBSIDY  HAS_DRIVE_LICENSE_CODE HAS_DRIVE_LICENSE AGE_CODE  \
# 0                   NaN                     1.0               Yes  AG65-74
# 1                   NaN                     2.0                No  AG55-64
# 2      None of the cost                     2.0                No  AG18-24
# 3      None of the cost                     1.0               Yes  AG65-74
# 4      None of the cost                     1.0               Yes  AG25-34
# ...                 ...                     ...               ...      ...
# 30600               NaN                     NaN               NaN      NaN
# 30601               NaN                     NaN               NaN      NaN
# 30602               NaN                     NaN               NaN      NaN
# 30603               NaN                     NaN               NaN      NaN
# 30604               NaN                     NaN               NaN      NaN
#
#          AGE AMERICAN_INDIAN_ALASKAN_NATIVE ASIAN BLACK_AFRICAN_AMERICAN  \
# 0      65-74                             No    No                     No
# 1      55-64                             No    No                    Yes
# 2      18-24                             No    No                    Yes
# 3      65-74                             No    No                     No
# 4      25-34                             No    No                     No
# ...      ...                            ...   ...                    ...
# 30600    NaN                            NaN   NaN                    NaN
# 30601    NaN                            NaN   NaN                    NaN
# 30602    NaN                            NaN   NaN                    NaN
# 30603    NaN                            NaN   NaN                    NaN
# 30604    NaN                            NaN   NaN                    NaN
#
#       HISPANIC_LATINO NATIVE_HAWAIIAN_PACIFIC_ISLANDER WHITE  \
# 0                  No                               No   Yes
# 1                  No                               No    No
# 2                  No                               No    No
# 3                  No                               No   Yes
# 4                  No                               No   Yes
# ...               ...                              ...   ...
# 30600             NaN                              NaN   NaN
# 30601             NaN                              NaN   NaN
# 30602             NaN                              NaN   NaN
# 30603             NaN                              NaN   NaN
# 30604             NaN                              NaN   NaN
#
#       RACE_ETHNICITY_OTHER  INCOME_CODE              INCOME  \
# 0                      NaN          4.0  $35,000 -  $59,999
# 1                      NaN          1.0   Less than $15,000
# 2                      NaN          1.0   Less than $15,000
# 3                      NaN          3.0   $25,000 - $34,999
# 4                      NaN          3.0   $25,000 - $34,999
# ...                    ...          ...                 ...
# 30600                  NaN          NaN                 NaN
# 30601                  NaN          NaN                 NaN
# 30602                  NaN          NaN                 NaN
# 30603                  NaN          NaN                 NaN
# 30604                  NaN          NaN                 NaN
#
#        HOME_LANG_OTHER_CODE HOME_LANG_OTHER  HOME_OTHER_LANG_CODE  \
# 0                       1.0             Yes                 297.0
# 1                       2.0              No                   NaN
# 2                       2.0              No                   NaN
# 3                       2.0              No                   NaN
# 4                       2.0              No                   NaN
# ...                     ...             ...                   ...
# 30600                   NaN             NaN                   NaN
# 30601                   NaN             NaN                   NaN
# 30602                   NaN             NaN                   NaN
# 30603                   NaN             NaN                   NaN
# 30604                   NaN             NaN                   NaN
#
#       HOME_OTHER_LANG HOME_OTHER_LANG_OTHER ENGLISH_ABILITY_CODE  \
# 0           Norwegian                   NaN                   A1
# 1                 NaN                   NaN                  NaN
# 2                 NaN                   NaN                  NaN
# 3                 NaN                   NaN                  NaN
# 4                 NaN                   NaN                  NaN
# ...               ...                   ...                  ...
# 30600             NaN                   NaN                  NaN
# 30601             NaN                   NaN                  NaN
# 30602             NaN                   NaN                  NaN
# 30603             NaN                   NaN                  NaN
# 30604             NaN                   NaN                  NaN
#
#       ENGLISH_ABILITY  DISABILITY_CODE DISABILITY  GREEN_LINE_INFO_CODE  \
# 0           Very well              1.0        Yes                   NaN
# 1                 NaN              1.0        Yes                   NaN
# 2                 NaN              1.0        Yes                   NaN
# 3                 NaN              1.0        Yes                   NaN
# 4                 NaN              1.0        Yes                   NaN
# ...               ...              ...        ...                   ...
# 30600             NaN              NaN        NaN                   NaN
# 30601             NaN              NaN        NaN                   NaN
# 30602             NaN              NaN        NaN                   NaN
# 30603             NaN              NaN        NaN                   NaN
# 30604             NaN              NaN        NaN                   NaN
#
#       GREEN_LINE_INFO  GREEN_INFO2_CODE GREEN_INFO2  GENDER_CODE  GENDER  \
# 0                 NaN               NaN         NaN          1.0    Male
# 1                 NaN               NaN         NaN          1.0    Male
# 2                 NaN               NaN         NaN          2.0  Female
# 3                 NaN               NaN         NaN          1.0    Male
# 4                 NaN               NaN         NaN          2.0  Female
# ...               ...               ...         ...          ...     ...
# 30600             NaN               NaN         NaN          NaN     NaN
# 30601             NaN               NaN         NaN          NaN     NaN
# 30602             NaN               NaN         NaN          NaN     NaN
# 30603             NaN               NaN         NaN          NaN     NaN
# 30604             NaN               NaN         NaN          NaN     NaN
#
#       H_TAZ O_TAZ D_TAZ   B_TAZ   A_TAZ     WGHT_NAME  UNLINKED_WGHT_FCTR  \
# 0      1500  1362  1505  1325.0  1508.0  BLUE_S_2_7_4             4.50950
# 1      1303  1303  2162  1509.0  1530.0  BLUE_S_2_3_1             4.37196
# 2      1199  1302  1199  1302.0  1221.0     5_N_2_2_3            20.69133
# 3       497   497  1325  1530.0  1324.0  BLUE_N_3_1_7             5.42903
# 4      2037  1502  1325  1502.0  1325.0  BLUE_N_3_4_6             6.80742
# ...     ...   ...   ...     ...     ...           ...                 ...
# 30600   NaN   NaN   NaN     NaN     NaN  BLUE_S_3_2_3            43.30305
# 30601   NaN   NaN   NaN     NaN     NaN  BLUE_S_4_1_2             4.19842
# 30602   NaN   NaN   NaN     NaN     NaN  BLUE_S_4_7_7            41.81050
# 30603   NaN   NaN   NaN     NaN     NaN  BLUE_S_4_7_7            41.81050
# 30604   NaN   NaN   NaN     NaN     NaN  BLUE_S_4_7_7            41.81050
#
#        TOTAL_TRANSFERS  LINKED_MULTIPLIER  LINKED_WGHT_FCTR  \
# 0                  2.0           0.333333           1.50317
# 1                  3.0           0.250000           1.09299
# 2                  0.0           1.000000          20.69133
# 3                  1.0           0.500000           2.71451
# 4                  0.0           1.000000           6.80742
# ...                ...                ...               ...
# 30600              NaN                NaN               NaN
# 30601              NaN                NaN               NaN
# 30602              NaN                NaN               NaN
# 30603              NaN                NaN               NaN
# 30604              NaN                NaN               NaN
#
#                                                    ROUTE ROUTE_PROVIDER  \
# 0                                   BLUE METRO Blue Line  Metro Transit
# 1                                   BLUE METRO Blue Line  Metro Transit
# 2      5 Brklyn Center - Fremont - 26th Av - Chicago ...  Metro Transit
# 3                                   BLUE METRO Blue Line  Metro Transit
# 4                                   BLUE METRO Blue Line  Metro Transit
# ...                                                  ...            ...
# 30600                               BLUE METRO Blue Line  Metro Transit
# 30601                               BLUE METRO Blue Line  Metro Transit
# 30602                               BLUE METRO Blue Line  Metro Transit
# 30603                               BLUE METRO Blue Line  Metro Transit
# 30604                               BLUE METRO Blue Line  Metro Transit
#
#         ROUTE_TYPE  TOTAL_TRANSFERS_WITHIN_SYSTEM Manual_Adjustment  \
# 0             Rail                            2.0                 0
# 1             Rail                            3.0                 0
# 2      Urban Local                            0.0                 0
# 3             Rail                            1.0                 0
# 4             Rail                            0.0                 0
# ...            ...                            ...               ...
# 30600         Rail                            NaN                 0
# 30601         Rail                            NaN                 0
# 30602         Rail                            NaN                 0
# 30603         Rail                            NaN                 0
# 30604         Rail                            NaN                 0
#
#                                        PNR_Lot_Used  \
# 0                                            NonPNR
# 1                                            NonPNR
# 2                                            NonPNR
# 3      Cedar Grove Transit Station @ 4035 Nicols Rd
# 4                                            NonPNR
# ...                                             ...
# 30600                                        NonPNR
# 30601                                        NonPNR
# 30602                                        NonPNR
# 30603                                        NonPNR
# 30604                                        NonPNR
#
#                                    PNR_Lot_Used-adj  \
# 0                                            NonPNR
# 1                                            NonPNR
# 2                                            NonPNR
# 3      Cedar Grove Transit Station @ 4035 Nicols Rd
# 4                                            NonPNR
# ...                                             ...
# 30600                                        NonPNR
# 30601                                        NonPNR
# 30602                                        NonPNR
# 30603                                        NonPNR
# 30604                                        NonPNR
#
#        Unlinked_Factor_-_Auto_Occ        WGHT_NAME_PNR  PNR_Factor    Exp_PNR  \
# 0                        4.509502  BLUE_S_2_7_4_NonPNR     1.00000   4.509502
# 1                        4.371955  BLUE_S_2_3_1_NonPNR     1.00000   4.371955
# 2                       20.691333     5_N_2_2_3_NonPNR     1.00000  20.691333
# 3                        5.429025     BLUE_N_3_1_7_PNR     0.51574   2.799964
# 4                        6.807419  BLUE_N_3_4_6_NonPNR     1.00000   6.807419
# ...                           ...                  ...         ...        ...
# 30600                   43.303047  BLUE_S_3_2_3_NonPNR     1.00000  43.303047
# 30601                    4.198416  BLUE_S_4_1_2_NonPNR     1.00000   4.198416
# 30602                   41.810497  BLUE_S_4_7_7_NonPNR     1.00000  41.810497
# 30603                   41.810497  BLUE_S_4_7_7_NonPNR     1.00000  41.810497
# 30604                   41.810497  BLUE_S_4_7_7_NonPNR     1.00000  41.810497
#
#        Final_AE_Factor  Unlinked_Weight-AE  Linked_Weight-AE Payment_Type_  \
# 0             1.000000            4.509502          1.503167   non-student
# 1             1.029373            4.500372          1.125093   non-student
# 2             1.000000           20.691333         20.691333   non-student
# 3             0.515740            2.799964          1.399982   non-student
# 4             1.021177            6.951580          6.951580   non-student
# ...                ...                 ...               ...           ...
# 30600         1.000000           43.303047               NaN   non-student
# 30601         1.000000            4.198416               NaN   non-student
# 30602         1.000000           41.810497               NaN   non-student
# 30603         1.000000           41.810497               NaN   non-student
# 30604         1.000000           41.810497               NaN   non-student
#
#       Route                            Boarding  \
# 0      Blue            HL 101 Warehouse Station
# 1      Blue          HL 108 38th Street Station
# 2         5                                   5
# 3      Blue      HL 117 Mall Of America Station
# 4      Blue  HL 111 Veterans Medical Center Sta
# ...     ...                                 ...
# 30600  Blue                                 NaN
# 30601  Blue                                 NaN
# 30602  Blue                                 NaN
# 30603  Blue                                 NaN
# 30604  Blue                                 NaN
#
#                                      Boarding_Student  \
# 0                HL 101 Warehouse Station-non-student
# 1              HL 108 38th Street Station-non-student
# 2                                       5-non-student
# 3          HL 117 Mall Of America Station-non-student
# 4      HL 111 Veterans Medical Center Sta-non-student
# ...                                               ...
# 30600                                             NaN
# 30601                                             NaN
# 30602                                             NaN
# 30603                                             NaN
# 30604                                             NaN
#
#               WGHT_NAME_Student  c_pass_factor  upass_factor  HS_Pass_factor  \
# 0      BLUE_S_2_7_4_non-student       2.183063      1.752921        1.615427
# 1      BLUE_S_2_3_1_non-student       2.190437      0.946854        3.431832
# 2         5_N_2_2_3_non-student       0.623818      0.236022        1.152726
# 3      BLUE_N_3_1_7_non-student       3.635399      3.457949        4.317363
# 4      BLUE_N_3_4_6_non-student       1.843609      3.231443        1.501410
# ...                         ...            ...           ...             ...
# 30600  BLUE_S_3_2_3_non-student            NaN           NaN             NaN
# 30601  BLUE_S_4_1_2_non-student            NaN           NaN             NaN
# 30602  BLUE_S_4_7_7_non-student            NaN           NaN             NaN
# 30603  BLUE_S_4_7_7_non-student            NaN           NaN             NaN
# 30604  BLUE_S_4_7_7_non-student            NaN           NaN             NaN
#
#        Exp_Student
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0
# ...            ...
# 30600          1.0
# 30601          1.0
# 30602          1.0
# 30603          1.0
# 30604          1.0
#
# [30605 rows x 179 columns]

# %%
print("Total entries in the on board survey:", len(obs_df))
print("Weighted total of entries in the on board survey:", obs_df['Unlinked_Weight-AE'].sum())
# Out:
# Total entries in the on board survey: 30605
# Weighted total of entries in the on board survey: 350474.127932107

# %% [markdown]
# # Transit Onboard Survey Data Coding

# %% [markdown]
# ## Recode relevant variables to match between each dataset

# %%
obs_df_orig = obs_df.copy()

list(obs_df)
# Out:
# ['ID',
#  'DATE',
#  'ROUTE_SURVEYED_CODE',
#  'ROUTE_SURVEYED',
#  'HOME_OR_HOTEL_ADDR_CITY',
#  'HOME_OR_HOTEL_ADDR_STATE',
#  'HOME_OR_HOTEL_ADDR_ZIP',
#  'HOME_OR_HOTEL_ADDR_LAT_100M',
#  'HOME_OR_HOTEL_ADDR_LON_100M',
#  'BOARDING_LOCATION',
#  'BOARDING_STOPID',
#  'BOARDING_LAT',
#  'BOARDING_LON',
#  'TRANSFERS_FROM_CODE',
#  'TRANSFERS_FROM',
#  'TRANSFERS_FROM_FIRST_CODE',
#  'TRANSFERS_FROM_FIRST',
#  'TRANSFERS_FROM_FIRST_OTHER',
#  'TRANSFERS_FROM_SECOND_CODE',
#  'TRANSFERS_FROM_SECOND',
#  'TRANSFERS_FROM_SECOND_OTHER',
#  'TRANSFERS_FROM_THIRD_CODE',
#  'TRANSFERS_FROM_THIRD',
#  'TRANSFERS_FROM_THIRD_OTHER',
#  'TRANSFERS_FROM_FOURTH_CODE',
#  'TRANSFERS_FROM_FOURTH',
#  'ORIGIN_PLACE_TYPE_CODE',
#  'ORIGIN_PLACE_TYPE',
#  'ORIGIN_CITY',
#  'ORIGIN_STATE',
#  'ORIGIN_ZIP',
#  'ORIGIN_LAT_100M',
#  'ORIGIN_LON_100M',
#  'ACCESS_MODE_CODE',
#  'ACCESS_MODE',
#  'VEHICLE_ACCESS_PARK_YN_PNR_CODE',
#  'VEHICLE_ACCESS_PARK_YN_PNR',
#  'VEHICLE_ACCESS_PARK_PNR_CODE',
#  'VEHICLE_ACCESS_PARK_PNR',
#  'VEHICLE_ACCESS_PARK_PNR_OTHER',
#  'VEHICLE_ACCESS_DROPOFF',
#  'VEHICLE_ACCESS_DROPOFF_CITY',
#  'VEHICLE_ACCESS_DROPOFF_STATE',
#  'VEHICLE_ACCESS_DROPOFF_ZIP',
#  'VEHICLE_ACCESS_DROPOFF_LAT',
#  'VEHICLE_ACCESS_DROPOFF_LON',
#  'ALIGHTING_LOCATION',
#  'ALIGHTING_STOPID',
#  'ALIGHTING_LAT',
#  'ALIGHTING_LON',
#  'TRANSFERS_TO_CODE',
#  'TRANSFERS_TO',
#  'TRANSFERS_TO_FIRST_CODE',
#  'TRANSFERS_TO_FIRST',
#  'TRANSFERS_TO_FIRST_OTHER',
#  'TRANSFERS_TO_SECOND_CODE',
#  'TRANSFERS_TO_SECOND',
#  'TRANSFERS_TO_SECOND_OTHER',
#  'TRANSFERS_TO_THIRD_CODE',
#  'TRANSFERS_TO_THIRD',
#  'TRANSFERS_TO_THIRD_OTHER',
#  'TRANSFERS_TO_FOURTH_CODE',
#  'TRANSFERS_TO_FOURTH',
#  'DESTIN_PLACE_TYPE_CODE',
#  'DESTIN_PLACE_TYPE',
#  'DESTINATION_CITY',
#  'DESTINATION_STATE',
#  'DESTINATION_ZIP',
#  'DESTINATION_LAT_100M',
#  'DESTINATION_LON_100M',
#  'EGRESS_MODE_CODE',
#  'EGRESS_MODE',
#  'VEHICLE_EGRESS_PARK_YN_PNR_CODE',
#  'VEHICLE_EGRESS_PARK_YN_PNR',
#  'VEHICLE_EGRESS_PARK_PNR_CODE',
#  'VEHICLE_EGRESS_PARK_PNR',
#  'VEHICLE_EGRESS_PARK_PNR_OTHER',
#  'VEHICLE_EGRESS_DROPOFF',
#  'VEHICLE_EGRESS_DROPOFF_CITY',
#  'VEHICLE_EGRESS_DROPOFF_STATE',
#  'VEHICLE_EGRESS_DROPOFF_ZIP',
#  'VEHICLE_EGRESS_DROPOFF_LAT',
#  'VEHICLE_EGRESS_DROPOFF_LON',
#  'TIME_ON_CODE',
#  'TIME_ON',
#  'TIME_PERIOD',
#  'TRIP_IN_OPPOSITE_DIR_CODE',
#  'TRIP_IN_OPPOSITE_DIR',
#  'OPP_DIR_TRIP_TIME_CODE',
#  'OPP_DIR_TRIP_TIME',
#  'PAYMENT_METHOD_CODE',
#  'PAYMENT_METHOD',
#  'FARE_TYPE_CODE',
#  'FARE_TYPE',
#  'TRIP_PURPOSE_NO_OTHER_TRIP',
#  'TRIP_PURPOSE_BUY_A_MEAL_/_BEVERAGE',
#  'TRIP_PURPOSE_GO_TO_WORK',
#  'TRIP_PURPOSE_VISIT_FRIEND/RELATIVE_OR_ATTEND_RELIGIOUS/SOC_EVENT',
#  'TRIP_PURPOSE_GO_TO_SCHOOL',
#  'TRIP_PURPOSE_GO_SHOPPING',
#  'TRIP_PURPOSE_OTHER_ERRANDS',
#  'TRIP_PURPOSE_OTHER',
#  'VISITOR_CODE',
#  'VISITOR',
#  'COUNT_VH_HH_CODE',
#  'COUNT_VH_HH',
#  'CAN_USE_VEH_TRIP_CODE',
#  'CAN_USE_VEH_TRIP',
#  'COUNT_MEMBER_HH_CODE',
#  'COUNT_MEMBER_HH',
#  'COUNT_EMPLOYED_HH_CODE',
#  'COUNT_EMPLOYED_HH',
#  'STATUS_EMPLOYMENT_CODE',
#  'STATUS_EMPLOYMENT',
#  'STUDENT_STATUS_CODE',
#  'STUDENT_STATUS',
#  'FARE_SUBSIDY_CODE',
#  'FARE_SUBSIDY',
#  'HAS_DRIVE_LICENSE_CODE',
#  'HAS_DRIVE_LICENSE',
#  'AGE_CODE',
#  'AGE',
#  'AMERICAN_INDIAN_ALASKAN_NATIVE',
#  'ASIAN',
#  'BLACK_AFRICAN_AMERICAN',
#  'HISPANIC_LATINO',
#  'NATIVE_HAWAIIAN_PACIFIC_ISLANDER',
#  'WHITE',
#  'RACE_ETHNICITY_OTHER',
#  'INCOME_CODE',
#  'INCOME',
#  'HOME_LANG_OTHER_CODE',
#  'HOME_LANG_OTHER',
#  'HOME_OTHER_LANG_CODE',
#  'HOME_OTHER_LANG',
#  'HOME_OTHER_LANG_OTHER',
#  'ENGLISH_ABILITY_CODE',
#  'ENGLISH_ABILITY',
#  'DISABILITY_CODE',
#  'DISABILITY',
#  'GREEN_LINE_INFO_CODE',
#  'GREEN_LINE_INFO',
#  'GREEN_INFO2_CODE',
#  'GREEN_INFO2',
#  'GENDER_CODE',
#  'GENDER',
#  'H_TAZ',
#  'O_TAZ',
#  'D_TAZ',
#  'B_TAZ',
#  'A_TAZ',
#  'WGHT_NAME',
#  'UNLINKED_WGHT_FCTR',
#  'TOTAL_TRANSFERS',
#  'LINKED_MULTIPLIER',
#  'LINKED_WGHT_FCTR',
#  'ROUTE',
#  'ROUTE_PROVIDER',
#  'ROUTE_TYPE',
#  'TOTAL_TRANSFERS_WITHIN_SYSTEM',
#  'Manual_Adjustment',
#  'PNR_Lot_Used',
#  'PNR_Lot_Used-adj',
#  'Unlinked_Factor_-_Auto_Occ',
#  'WGHT_NAME_PNR',
#  'PNR_Factor',
#  'Exp_PNR',
#  'Final_AE_Factor',
#  'Unlinked_Weight-AE',
#  'Linked_Weight-AE',
#  'Payment_Type_',
#  'Route',
#  'Boarding',
#  'Boarding_Student',
#  'WGHT_NAME_Student',
#  'c_pass_factor',
#  'upass_factor',
#  'HS_Pass_factor',
#  'Exp_Student']

# %%
obs_df = obs_df_orig[['ID', 'ROUTE_SURVEYED_CODE', 'ROUTE_SURVEYED', 'ROUTE', 'ROUTE_PROVIDER','ORIGIN_PLACE_TYPE_CODE','ORIGIN_PLACE_TYPE', 
                      'ACCESS_MODE_CODE','ACCESS_MODE', 'EGRESS_MODE_CODE', 'EGRESS_MODE',
                     'DESTIN_PLACE_TYPE_CODE', 'DESTIN_PLACE_TYPE', 
                      'TIME_ON', 'TIME_PERIOD', 'TIME_ON_CODE',
                      'TRIP_PURPOSE_NO_OTHER_TRIP',
                     'TRIP_PURPOSE_BUY_A_MEAL_/_BEVERAGE',
                     'TRIP_PURPOSE_GO_TO_WORK',
                     'TRIP_PURPOSE_VISIT_FRIEND/RELATIVE_OR_ATTEND_RELIGIOUS/SOC_EVENT',
                     'TRIP_PURPOSE_GO_TO_SCHOOL',
                     'TRIP_PURPOSE_GO_SHOPPING',
                     'TRIP_PURPOSE_OTHER_ERRANDS',
                     'TRIP_PURPOSE_OTHER',
                      'COUNT_EMPLOYED_HH_CODE', 'COUNT_EMPLOYED_HH',
                      'COUNT_VH_HH_CODE', 'COUNT_VH_HH',
                      'COUNT_MEMBER_HH_CODE', 'COUNT_MEMBER_HH', 'STATUS_EMPLOYMENT', 'STUDENT_STATUS',
                    'HAS_DRIVE_LICENSE', 'AGE', 'INCOME_CODE', 'INCOME', 
                      'O_TAZ', 'D_TAZ', 'Unlinked_Weight-AE', 'Linked_Weight-AE']].copy()

# %% [markdown]
# ### Boardings by route
#
#
# Questions:

# %%
obs_route_df = obs_df.groupby(['ROUTE_PROVIDER'])['Unlinked_Weight-AE'].agg(sum).sort_index(level='ROUTE_PROVIDER').to_frame()
obs_route_df['Percent'] = obs_route_df['Unlinked_Weight-AE'] / obs_route_df['Unlinked_Weight-AE'].sum() * 100

# print(route_dict.head())
display(HTML(obs_route_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unlinked_Weight-AE</th>
#       <th>Percent</th>
#     </tr>
#     <tr>
#       <th>ROUTE_PROVIDER</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MVTA</th>
#       <td>10386.425806</td>
#       <td>2.963536</td>
#     </tr>
#     <tr>
#       <th>Maple Grove</th>
#       <td>3509.824504</td>
#       <td>1.001450</td>
#     </tr>
#     <tr>
#       <th>Met Council</th>
#       <td>11222.951323</td>
#       <td>3.202220</td>
#     </tr>
#     <tr>
#       <th>Metro Transit</th>
#       <td>297493.573266</td>
#       <td>84.883177</td>
#     </tr>
#     <tr>
#       <th>Plymouth</th>
#       <td>1829.987180</td>
#       <td>0.522146</td>
#     </tr>
#     <tr>
#       <th>Southwest</th>
#       <td>4286.000000</td>
#       <td>1.222915</td>
#     </tr>
#     <tr>
#       <th>U of M</th>
#       <td>21745.365854</td>
#       <td>6.204557</td>
#     </tr>
#   </tbody>
# </table>

# %%
def code_purpose(value):
    if (value == 2):
        return 'Work'
    elif (value == 1):
        return 'Home'
    elif (value == 3):
        return 'University'
    elif (value == 9): # airport
        return 'Maintenance'
    elif (value == 8): # social
        return 'Discretionary'
    elif (value == 5): # medical
        return 'Maintenance'
    elif (value == 7): # recreation
        return 'Discretionary'
    elif (value == 6): # shop
        return 'Maintenance'
    elif (value == 10): # sporting
         return 'Discretionary'
    elif (value == 'Shopping'):
        return 'Maintenance'
    elif (value == 11): # work related
        return 'Maintenance'
    
    elif (value == 12): # hotel
        return 'Maintenance'
    elif (value == 4):
        return 'K-12 school'
    elif (value == 99):
        return 'Maintenance'

# %%
obs_df['ORIG_PURPOSE'] = obs_df['ORIGIN_PLACE_TYPE_CODE'].apply(lambda value: code_purpose(value))

obs_df['DEST_PURPOSE'] = obs_df['DESTIN_PLACE_TYPE_CODE'].apply(lambda value: code_purpose(value))

# %%
print(obs_df['ORIG_PURPOSE'].value_counts())
print(obs_df['DEST_PURPOSE'].value_counts())
# Out:
# Home             15295
# Work              8175
# Discretionary     2856
# Maintenance       2014
# University        1629
# K-12 school        483
# Name: ORIG_PURPOSE, dtype: int64
# Home             11691
# Work              9339
# Discretionary     4294
# Maintenance       2403
# University        2170
# K-12 school        573
# Name: DEST_PURPOSE, dtype: int64

# %% [markdown]
# ### Access mode
#
# * 1 - PNR (driving, carshare)
# * 2 - KNR (dropped off, taxi/TNC)
# * 3 - Walk (includes bike, scooter, skateboard)
#
# Questions:
# * Should taxi be TNC?

# %%
# Code access/egress before imputation

def code_access_mode(value):
    if (value in  [4, 9, 10, 3, 12, 8]):
        return 'KNR'
    elif (value in [7, 6, 5]):
        return 'PNR'
    return 'Walk'


obs_df['access_mode'] = obs_df['ACCESS_MODE_CODE'].apply(lambda value: code_access_mode(value))
obs_df['egress_mode'] = obs_df['EGRESS_MODE_CODE'].apply(lambda value: code_access_mode(value))

# %%
orig_dest_ct = pd.crosstab(obs_df['access_mode'], obs_df['egress_mode'], values=obs_df['Unlinked_Weight-AE'], aggfunc=sum, margins=True)
orig_dest_ct = add_percentage_to_crosstab(orig_dest_ct)
orig_dest_ct.fillna(0, inplace=True)
orig_dest_ct.applymap(lambda x: round(x,2))
# Out:
# egress_mode       KNR       PNR       Walk        All  Percent
# access_mode
# KNR           3965.11    125.69    8574.30   12665.11     3.61
# PNR             98.44    302.24   19553.46   19954.14     5.69
# Walk          6329.09  18673.86  292851.93  317854.88    90.69
# All          10392.64  19101.79  320979.69  350474.13   100.00
# Percent          2.97      5.45      91.58     100.00     0.00

# %% [markdown]
# ### Auto Sufficiency
# * 0 for households with no autos
# * 1 for households that have 0 < autos < number of workers
# * 2 for households that have 0 < autos >= number of workers
#
# Questions:
# * Auto suff for Metra was imputed in R based on CMAP data
#   * Mainly resulted in auto suff "vehicles greater than or equal to workers"
#   * Does that make sense for commuter rail?
# * Some missing hh employed or hh veh in CTA

# %%
obs_df['auto_suff'] = -1

# %%
obs_df.loc[obs_df.COUNT_VH_HH_CODE != '10P', 'hh_veh'] = obs_df.COUNT_VH_HH_CODE
obs_df.loc[obs_df.COUNT_VH_HH_CODE == '10P','hh_veh'] = 10
obs_df['hh_veh'] = pd.to_numeric(obs_df['hh_veh'])

obs_df.loc[pd.isna(obs_df.COUNT_EMPLOYED_HH_CODE), 'hh_employed'] = 0

obs_df['hh_employed'] = pd.to_numeric(obs_df['COUNT_EMPLOYED_HH_CODE'])
obs_df.loc[obs_df.hh_veh < obs_df.hh_employed, 'auto_suff'] = 1
obs_df.loc[obs_df.hh_veh >= obs_df.hh_employed, 'auto_suff'] = 2
obs_df.loc[obs_df.hh_veh == 0, 'auto_suff'] = 0

# %%
print(obs_df['auto_suff'].value_counts(normalize = True))
print(obs_df[obs_df['auto_suff'] >=0]['auto_suff'].value_counts(normalize = True))
print(obs_df['hh_veh'].value_counts())
print(obs_df['hh_employed'].value_counts())
# Out:
#  2    0.366509
#  0    0.325241
#  1    0.258585
# -1    0.049665
# Name: auto_suff, dtype: float64
# 2    0.385663
# 0    0.342238
# 1    0.272099
# Name: auto_suff, dtype: float64
# 0.0     9954
# 1.0     8978
# 2.0     7264
# 3.0     2016
# 4.0      591
# 5.0      184
# 6.0       54
# 10.0      23
# 7.0       13
# 8.0        5
# 9.0        3
# Name: hh_veh, dtype: int64
# 2.0     11801
# 1.0      8619
# 3.0      4030
# 0.0      2417
# 4.0      1485
# 5.0       437
# 6.0       142
# 10.0       75
# 7.0        46
# 8.0        22
# 9.0        11
# Name: hh_employed, dtype: int64

# %%
# impute autosuff based on overall distribution

# 0    0.342
# 1    0.272
# 2    0.386
random.seed(413)

m = obs_df[obs_df['auto_suff']<0].shape[0]

s = np.random.choice([0, 1, 2],
                     p=[ 0.342, 0.272,0.386], 
                     size = m)
print(s)

obs_df.loc[obs_df['auto_suff'] < 0, 'auto_suff'] = s
# Out:
# [1 2 1 ... 1 1 0]

# %%
# # Scale to boardings in oct 2018
# pd.set_option('display.max_rows', 130)

# metcouncil_boardings = ...

# Assume updated weights will have right boarding sum?
# Scale missing purposes


weight_sum = obs_df.Unlinked_Weight-AE.sum()
linked_weight_sum =  obs_df.Linked_Weight-AE.sum()
obs_df = obs_df[~obs_df['TOUR_PURPOSE'].isnull()]

weight_sum_2 =  obs_df.Unlinked_Weight-AE.sum()
linked_weight_sum_2 =  obs_df.Linked_Weight-AE.sum()

obs_df['unlinked_weight_scaled'] = obs_df['Unlinked_Weight-AE'] * (weight_sum/weight_sum_2)
obs_df['linked_weight_scaled'] = obs_df['Linked_Weight-AE'] * (linked_weight_sum/linked_weight_sum_2)
print('scaled weights')
print(obs_df.unlinked_weight_scaled.sum())
print(obs_df.linked_weight_scaled.sum())

# %% [markdown]
# #### Impute tour purposes for non-work tours:
#
# Impute work tours/sub-tours and joint tour purposes where applicable using time of day.
#
# * Impute work tours from maintenance/discretionary tours
# * Impute work sub-tours where neither end is home
# * Impute joint tours from maintenance/discretionary tours that remain
#
# Metra is only first half of the day, so have to do it on regular metra dataset before combining

# %%
obs_df.TIME_ON.value_counts()
# metra_df.Time.value_counts()
# Out:
# 7:00 - 8:00 am         3526
# 4:00 - 5:00 pm         3290
# 5:00 - 6:00 pm         2827
# 8:00 - 9:00 am         2688
# 3:00 - 4:00 pm         2527
# 10:00 - 11:00 am       2053
# 9:00 - 10:00 am        2050
# 6:00 - 7:00 am         1905
# 7:00 - 8:00 pm         1801
# 11:00 am - 12:00 pm    1422
# 12:00 pm - 1:00 pm     1189
# 6:30 - 7:00 pm         1088
# 2:00 - 3:00 pm         1068
# 6:00 - 6:30 pm         1031
# 1:00 - 2:00 pm          705
# 8:00 - 9:00 pm          653
# 11:00 - 12:00 pm        525
# Before 6:00 am          117
# After 9:00 pm            26
# Name: TIME_ON, dtype: int64

# %% [markdown]
# ### Tour Purpose
#
# * Work (home-based-work or work-based tour)
# * School
# * Other - use a hierarchy

# %%
purpose_ct = pd.crosstab(
    obs_df['ORIG_PURPOSE'],
    obs_df['DEST_PURPOSE'],
    values=obs_df['unlinked_weight_scaled'],
    aggfunc=sum,
    normalize='all',
    margins=True)*100
# purpose_ct = add_percentage_to_crosstab(purpose_ct)
# purpose_ct.fillna(0, inplace=True)
purpose_ct.applymap(lambda x: round(x,2))
# Out:
# DEST_PURPOSE   Discretionary   Home  K-12 school  Maintenance  University  \
# ORIG_PURPOSE
# Discretionary           2.00   5.48         0.12         0.83        0.43
# Home                    9.14   0.02         1.98         5.48        6.80
# K-12 school             0.20   1.41         0.02         0.03        0.05
# Maintenance             0.82   4.82         0.03         0.50        0.08
# University              0.64   4.58         0.02         0.14        1.27
# Work                    1.93  21.42         0.02         0.69        0.37
# All                    14.73  37.73         2.18         7.68        8.99
#
# DEST_PURPOSE    Work     All
# ORIG_PURPOSE
# Discretionary   1.01    9.87
# Home           26.17   49.58
# K-12 school     0.13    1.84
# Maintenance     0.35    6.60
# University      0.42    7.07
# Work            0.62   25.05
# All            28.69  100.00

# %%
def determine_tour_purpose(orig_purpose, dest_purpose):
    if (orig_purpose == 'Work') & (dest_purpose == 'Work'):
        return 'Work sub-tour'
    if (orig_purpose == 'Work') | (dest_purpose == 'Work'):
        return 'Work'
    if (orig_purpose == 'Other work') | (dest_purpose == 'Other work'):
        return 'Maintenance'
    if (orig_purpose == 'University') | (dest_purpose == 'University'):
        return 'University'
    if (orig_purpose == 'K-12 school') | (dest_purpose == 'K-12 school'):
        return 'School'
    if (orig_purpose == 'Maintenance') | (dest_purpose == 'Maintenance'):
        return 'Maintenance'
    if (orig_purpose == 'Discretionary') | (dest_purpose == 'Discretionary'):
        return 'Discretionary'
    if (orig_purpose == 'Home') & (dest_purpose != 'Home'):
        return dest_purpose
    if (orig_purpose != 'Home') & (dest_purpose == 'Home'):
        return orig_purpose
    if (orig_purpose == 'Home') & (dest_purpose == 'Home'):
        return 'Discretionary'
    if orig_purpose == dest_purpose:
        return orig_purpose
    return dest_purpose

obs_df['TOUR_PURPOSE'] = obs_df.apply(lambda row: determine_tour_purpose(row['ORIG_PURPOSE'], row['DEST_PURPOSE']), axis=1)

# home-home as other discrectionary
# Social/visiting vs. other discretionary
# Recreation & sporting in "other discretionary"

# %%
# use trip weights instead
obs_df['TOUR_PURPOSE'].value_counts(dropna=False)
obs_df.groupby(['TOUR_PURPOSE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_PURPOSE')
# Out:
# TOUR_PURPOSE
# Discretionary     43947.135357
# Maintenance       33830.761677
# School             8937.711657
# University        40840.006454
# Work             143004.575059
# Work sub-tour      1795.336742
# Name: linked_weight_scaled, dtype: float64

# %%
obs_df.groupby(['TOUR_PURPOSE'])['unlinked_weight_scaled'].agg(sum).sort_index(level='TOUR_PURPOSE')
# Out:
# TOUR_PURPOSE
# Discretionary     57623.737580
# Maintenance       43276.612717
# School            13089.678623
# University        48400.142401
# Work             181512.159441
# Work sub-tour      2130.976978
# Name: unlinked_weight_scaled, dtype: float64

# %%
# access/egress individually coded earlier
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# code access based on both access/egress
def determine_tour_mode(row):
    if (row['access_mode'] == 'PNR') | (row['egress_mode'] == 'PNR'):
        return 'PNR'
    if (row['access_mode'] == 'TNR') | (row['egress_mode'] == 'TNR'):
        return 'TNR'
    if (row['access_mode'] == 'KNR') | (row['egress_mode'] == 'KNR'):
        return 'KNR'
    return 'Walk'

obs_df['TOUR_MODE'] = obs_df.apply(lambda row: determine_tour_mode(row), axis=1)
access_df = obs_df.groupby(['TOUR_MODE'])['unlinked_weight_scaled'].agg(sum).sort_index(level='TOUR_MODE').to_frame()
access_df['Percent'] = access_df['unlinked_weight_scaled'] / access_df['unlinked_weight_scaled'].sum() * 100



print(access_df)

obs_df.groupby(['TOUR_MODE'])['unlinked_weight_scaled'].agg(sum).sort_index(level='TOUR_MODE')
# Out:
#            unlinked_weight_scaled  Percent
# TOUR_MODE
# KNR                     18868.504    5.384
# PNR                     38753.693   11.058
# Walk                   292851.931   83.559
# TOUR_MODE
# KNR     18868.504
# PNR     38753.693
# Walk   292851.931
# Name: unlinked_weight_scaled, dtype: float64

# %%
# derive TOD/use CMAP utilities for now

obs_df.loc[(obs_df['TIME_ON_CODE']>=5) & (obs_df['TIME_ON_CODE'] <=11), 'TOD'] = '9:01 am - 3:00 pm'
obs_df.loc[(obs_df['TIME_ON_CODE']>=6) & (obs_df['TIME_ON_CODE'] <=9), 'TOD'] = '10:01 am - 2:00 pm'

# %%
# Impute work tour purpose
# Limit to workers, tour purpose is maintenance/discretionary
# limit to weekdays? need to ask -- Day_Type_2 == 1

obs_df['TOUR_PURPOSE_INIT'] = obs_df['TOUR_PURPOSE']
obs_df['imputed_tour_purpose'] = ''

# calculate utility work tour based on model coefficients
obs_df['uWTP'] = -0.480

# original tour purpose
obs_df.loc[(obs_df['TOUR_PURPOSE_INIT'] == 'Discretionary'), 'uWTP'] = obs_df[obs_df['TOUR_PURPOSE_INIT'] == 'Discretionary']['uWTP'] + (-0.961)


# surveyed hour
obs_df.loc[(obs_df['TOD'] == '9:01 am - 3:00 pm'), 'uWTP'] = obs_df[(obs_df['TOD'] == '9:01 am - 3:00 pm')]['uWTP'] + (-1.21)
obs_df.loc[(obs_df['TIME_ON_CODE'] == 12), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 12)]['uWTP'] + (-0.197 ) # 4pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 13), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 13)]['uWTP'] + (-0.365) # 5pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 14) | (obs_df['TIME_ON_CODE'] == 15), 'uWTP'] = \
    obs_df[[(obs_df['TIME_ON_CODE'] == 14) | (obs_df['TIME_ON_CODE'] == 15)]['uWTP'] + (-0.932 ) # 6pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 15), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 16)]['uWTP'] + (-1.25) # 7pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 16), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 17)]['uWTP'] + (-1.46) # 8pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 17), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 18)]['uWTP'] + (-1.12) # >9pm

# access mode
obs_df.loc[(obs_df['TOUR_MODE'] == 'PNR'), 'uWTP'] = obs_df[(obs_df['TOUR_MODE'] == 'PNR')]['uWTP'] + (1.12) 
obs_df.loc[(obs_df['TOUR_MODE'] == 'KNR'), 'uWTP'] = obs_df[(obs_df['TOUR_MODE'] == 'KNR')]['uWTP'] + (1.78) 

# calculate probability
obs_df['expuWTP'] = np.exp(obs_df['uWTP'])
obs_df['probWTP'] = obs_df['expuWTP']/(1 + obs_df['expuWTP'])

print(obs_df['probWTP'].value_counts(dropna=False))

# Generate random number
np.random.seed(30)
obs_df['randn'] = np.random.uniform(0, 1, obs_df.shape[0])

obs_df.loc[(obs_df['randn'] < obs_df['probWTP']), 'imputed_tour_purpose'] = 'Work'
obs_df.loc[(obs_df['randn'] >= obs_df['probWTP']), 'imputed_tour_purpose'] = 'replace'


print(np.mean(obs_df['probWTP']))
print(obs_df[obs_df['imputed_tour_purpose'] == 'Work'].shape[0]/
      (obs_df[obs_df['imputed_tour_purpose'] == 'Work'].shape[0] + 
       obs_df[obs_df['imputed_tour_purpose'] == 'replace'].shape[0]))

obs_df.loc[(obs_df['hh_employed'] > 0) & 
           (obs_df['imputed_tour_purpose'] == 'Work') & 
           (obs_df['TOUR_PURPOSE_INIT'].isin(['Maintenance', 'Discretionary'])), 'TOUR_PURPOSE'] = obs_df[(obs_df['hh_employed'] > 0) & 
               (obs_df['imputed_tour_purpose'] == 'Work') & 
               (obs_df['TOUR_PURPOSE_INIT'].isin(['Maintenance', 'Discretionary']))]['imputed_tour_purpose']

obs_df.groupby(['TOUR_PURPOSE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_PURPOSE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c449978e074> in <module>
#       3 # limit to weekdays? need to ask -- Day_Type_2 == 1
#       4
# ----> 5 obs_df['TOUR_PURPOSE_INIT'] = obs_df['TOUR_PURPOSE']
#       6 obs_df['imputed_tour_purpose'] = ''
#       7
#
# NameError: name 'obs_df' is not defined

# %%
# Derive observed/surveyed hour (as a sub for departure hour)


# # pd.to_datetime(obs_df['StartTime']).head()
# obs_df['surveyed_hour'] = pd.to_datetime(obs_df['StartTime']).dt.hour

# obs_df['surveyed_hour'].value_counts(dropna=False).sort_index(level='surveyed_hour')

# %%
# Impute work sub-tour purpose
# Limit to origin/destination not home

# calculate utility work subtour based on model coefficients
obs_df['uWST'] = -5.16

obs_df.loc[(obs_df['ORIG_PURPOSE'] == 'Work') | (obs_df['DEST_PURPOSE'] == 'Work'), 'uWST'] = \
    obs_df[(obs_df['ORIG_PURPOSE'] == 'Work') | (obs_df['DEST_PURPOSE'] == 'Work')]['uWST'] + (2.68 )
obs_df.loc[(obs_df['TOD'] == '10:01 am - 2:00 pm'), 'uWST'] = obs_df[(obs_df['TOD'] == '10:01 am - 2:00 pm')]['uWST'] + (1.63)
obs_df.loc[(obs_df['TIME_ON_CODE'] == 8), 'uWST'] = obs_df[(obs_df['TIME_ON_CODE'] == 8)]['uWST'] + (0.458)



# calculate probability
obs_df['expuWST'] = np.exp(obs_df['uWST'])
obs_df['probWST'] = obs_df['expuWST']/(1 + obs_df['expuWST'])

print(obs_df['probWST'].value_counts(dropna=False))

# Generate random number
obs_df['randn'] = np.random.uniform(0, 1, obs_df.shape[0])

obs_df.loc[(obs_df['randn'] < obs_df['probWST']), 'imputed_tour_purpose'] = 'Work sub-tour'
obs_df.loc[(obs_df['randn'] >= obs_df['probWST']), 'imputed_tour_purpose'] = 'replace'


print(np.mean(obs_df['probWST']))
print(obs_df[obs_df['imputed_tour_purpose'] == 'Work sub-tour'].shape[0]/
      (obs_df[obs_df['imputed_tour_purpose'] == 'Work sub-tour'].shape[0] + 
       obs_df[obs_df['imputed_tour_purpose'] == 'replace'].shape[0]))

obs_df.loc[(obs_df['imputed_tour_purpose'] == 'Work sub-tour') & 
           (obs_df['ORIG_PURPOSE'] != 'Home') & 
           (obs_df['DEST_PURPOSE'] != 'Home'), 'TOUR_PURPOSE'] = obs_df[(obs_df['imputed_tour_purpose'] == 'Work sub-tour') & 
           (obs_df['ORIG_PURPOSE'] != 'Home') & 
           (obs_df['DEST_PURPOSE'] != 'Home')]['imputed_tour_purpose']

obs_df.groupby(['TOUR_PURPOSE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_PURPOSE')
# Out:
# 0.031    13803
# 0.001     7790
# 0.014     5483
# 0.423     3529
# Name: probWST, dtype: int64
# 0.06536853912131782
# 0.06606763600718837
# TOUR_PURPOSE
# Discretionary    38870.524
# Maintenance      27482.198
# School            8935.734
# University       40832.396
# Work            151421.823
# Work sub-tour     4812.851
# Name: linked_weight_scaled, dtype: float64

# %%
obs_df.COUNT_MEMBER_HH_CODE.value_counts()
# Out:
# 2.000     8502
# 1.000     6140
# 3.000     5457
# 4.000     4733
# 5.000     2417
# 6.000     1010
# 7.000      321
# 10.000     231
# 8.000      197
# 9.000       77
# Name: COUNT_MEMBER_HH_CODE, dtype: int64

# %%
# Impute joint tour
# Limit to hhsize >1 and maintenance/discretionary tour purpose (after prev steps)

# calculate utility fully joint tour based on model coefficients
obs_df['uFJT'] = -2.65

# surveyed hour
obs_df.loc[(obs_df['TOD'] == '9:01 am - 3:00 pm'), 'uFJT'] = obs_df[(obs_df['TOD'] == '9:01 am - 3:00 pm')]['uFJT'] + (0.567)
obs_df.loc[(obs_df['TIME_ON_CODE'] == 12), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 12)]['uWTP'] + (0.3547 ) # 4pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 13), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 13)]['uWTP'] + (0.643) # 5pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 14) | (obs_df['TIME_ON_CODE'] == 15), 'uWTP'] = \
    obs_df[[(obs_df['TIME_ON_CODE'] == 14) | (obs_df['TIME_ON_CODE'] == 15)]['uWTP'] + (1.02 ) # 6pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 15), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 16)]['uWTP'] + (1.23) # 7pm
obs_df.loc[(obs_df['TIME_ON_CODE'] == 16), 'uWTP'] = obs_df[(obs_df['TIME_ON_CODE'] == 17)]['uWTP'] + ( 0.997  ) # 8pm
obs_df.loc[(obs_df['TOUR_PURPOSE_INIT'] == 'Discretionary'), 'uFJT'] = obs_df[(obs_df['TOUR_PURPOSE_INIT'] == 'Discretionary')]['uFJT'] + (0.227)
obs_df.loc[(obs_df['TOUR_PURPOSE_INIT'] == 'Maintenance'), 'uFJT'] = obs_df[(obs_df['TOUR_PURPOSE_INIT'] == 'Maintenance')]['uFJT'] + (-0.197)

# calculate probability
obs_df['expuFJT'] = np.exp(obs_df['uFJT'])
obs_df['probFJT'] = obs_df['expuFJT']/(1 + obs_df['expuFJT'])

print(obs_df['probFJT'].value_counts(dropna=False))

# Generate random number
obs_df['randn'] = np.random.uniform(0, 1, obs_df.shape[0])

obs_df.loc[(obs_df['randn'] < obs_df['probFJT']), 'joint_tour_type'] = 'Joint'
obs_df.loc[(obs_df['randn'] >= obs_df['probFJT']), 'joint_tour_type'] = 'Ind'


print(np.mean(obs_df['probFJT']))
print(obs_df[obs_df['joint_tour_type'] == 'Joint'].shape[0]/
      (obs_df[obs_df['joint_tour_type'] == 'Joint'].shape[0] + 
       obs_df[obs_df['joint_tour_type'] == 'Ind'].shape[0]))

obs_df.loc[(obs_df['COUNT_MEMBER_HH_CODE'] > 1) & # hhsize > 1
           (obs_df['TOUR_PURPOSE'] == 'Discretionary') & 
           (obs_df['joint_tour_type'] == 'Joint'), 'TOUR_PURPOSE'] = 'Joint-Discretionary'

obs_df.loc[(obs_df['TOUR_PURPOSE'] == 'Discretionary'), 'TOUR_PURPOSE'] = 'Ind-Discretionary'

obs_df.loc[(obs_df['COUNT_MEMBER_HH_CODE'] > 1) & # hhsize > 1
           (obs_df['TOUR_PURPOSE'] == 'Maintenance') & 
           (obs_df['joint_tour_type'] == 'Joint'), 'TOUR_PURPOSE'] = 'Joint-Maintenance'

obs_df.loc[(obs_df['TOUR_PURPOSE'] == 'Maintenance'), 'TOUR_PURPOSE'] = 'Ind-Maintenance'


obs_df.groupby(['TOUR_PURPOSE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_PURPOSE')
# Out:
# 0.085    7753
# 0.035    7477
# 0.064    5292
# 0.120    1905
# 0.099    1815
# 0.156    1785
# 0.153    1350
# 0.130    1225
# 0.264     722
# 0.066     474
# 0.224     408
# 0.054     399
# Name: probFJT, dtype: int64
# 0.08647199083027453
# 0.08730599575232804
# TOUR_PURPOSE
# Ind-Discretionary      35180.161
# Ind-Maintenance        25842.787
# Joint-Discretionary     3690.363
# Joint-Maintenance       1639.411
# School                  8935.734
# University             40832.396
# Work                  151421.823
# Work sub-tour           4812.851
# Name: linked_weight_scaled, dtype: float64

# %%
obs_df.groupby(['TOUR_PURPOSE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_PURPOSE')
# Out:
# TOUR_PURPOSE
# Ind-Discretionary      35180.161
# Ind-Maintenance        25842.787
# Joint-Discretionary     3690.363
# Joint-Maintenance       1639.411
# School                  8935.734
# University             40832.396
# Work                  151421.823
# Work sub-tour           4812.851
# Name: linked_weight_scaled, dtype: float64

# %% [markdown]
# ## Combine with reverse metra data

# %%
make_percentage_bar_plot(
    variable='auto_suff',
    title="Auto Sufficiency",
    xlabel="Auto Sufficiency",
    xlabel_rotation=0)

# %%
make_percentage_bar_plot(
    variable='TOUR_PURPOSE',
    title="Inferred Tour Purpose",
    xlabel="Tour Purpose",
    xlabel_rotation=90)

# %%
obs_df['TOUR_MODE'] = obs_df.apply(lambda row: determine_tour_mode(row), axis=1)
access_df = obs_df.groupby(['TOUR_MODE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_MODE').to_frame()
access_df['Percent'] = access_df['linked_weight_scaled'] / access_df['linked_weight_scaled'].sum() * 100



print(access_df)

obs_df.groupby(['TOUR_MODE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_MODE')
# Out:
#            linked_weight_scaled  Percent
# TOUR_MODE
# KNR                   15510.404    5.695
# PNR                   35858.372   13.166
# Walk                 220993.939   81.140
# TOUR_MODE
# KNR     15510.404
# PNR     35858.372
# Walk   220993.939
# Name: linked_weight_scaled, dtype: float64

# %% [markdown]
# ## Summary tables

# %% [markdown]
# ### Boardings by line

# %%
obs_df.ROUTE.value_counts()
obs_df.groupby(['ROUTE'])['unlinked_weight_scaled'].agg(sum).sort_index(level='ROUTE')
# Out:
# ROUTE
# 10 Central Av - University Av - Northtown            7942.194
# 11 Columbia Heights - 2nd St NE - 4th Av S           4597.148
# 111 Ltd Stop - 66th St - Chicago - Cedar - U of M      85.820
# 113 Ltd Stop - Grand Av S - Lyndale Av S - U of M     563.478
# 114 Ltd Stop - Excelsior Blvd - Uptown - U of M       702.845
#                                                        ...
# 94 Express - Mpls - St Paul                          2314.735
# ALINE - A-Line Rapid Transit                         5133.203
# BLUE METRO Blue Line                                33050.048
# GREEN METRO Green Line                              46108.762
# RED METRO Red Line                                    954.004
# Name: unlinked_weight_scaled, Length: 217, dtype: float64

# %%
mode_df = obs_df.groupby(['TOUR_MODE'])['linked_weight_scaled'].agg(sum).sort_index(level='TOUR_MODE').to_frame()
mode_df['Percent'] = mode_df['linked_weight_scaled'] / mode_df['linked_weight_scaled'].sum() * 100
display(HTML(mode_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>linked_weight_scaled</th>
#       <th>Percent</th>
#     </tr>
#     <tr>
#       <th>TOUR_MODE</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>KNR</th>
#       <td>15510.404</td>
#       <td>5.695</td>
#     </tr>
#     <tr>
#       <th>PNR</th>
#       <td>35858.372</td>
#       <td>13.166</td>
#     </tr>
#     <tr>
#       <th>Walk</th>
#       <td>220993.939</td>
#       <td>81.140</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Linked trips by transit mode + tour purpose

# %%
mode_purpose_ct = pd.crosstab(obs_df['TOUR_PURPOSE'], obs_df['TOUR_MODE'], values=obs_df['linked_weight_scaled'], aggfunc=sum, margins=True)
mode_purpose_ct = add_percentage_to_crosstab(mode_purpose_ct)
mode_purpose_ct.fillna(0, inplace=True)
mode_purpose_ct.applymap(lambda x: round(x,2))
# Out:
# TOUR_MODE                 KNR       PNR       Walk        All  Percent
# TOUR_PURPOSE
# Ind-Discretionary    1846.770   649.540  32683.850  35180.160   12.920
# Ind-Maintenance      1134.720   503.790  24204.280  25842.790    9.490
# Joint-Discretionary   264.090   109.760   3316.520   3690.360    1.350
# Joint-Maintenance      55.710     5.640   1578.060   1639.410    0.600
# School                335.600    87.870   8512.270   8935.730    3.280
# University           2156.760  2774.890  35900.750  40832.400   14.990
# Work                 9431.060 31512.870 110477.900 151421.820   55.600
# Work sub-tour         285.700   214.020   4313.120   4812.850    1.770
# All                 15510.400 35858.370 220986.750 272355.530  100.000
# Percent                 5.690    13.170     81.140    100.000    0.000

# %% [markdown]
# ### Linked trips by tour purpose, auto sufficiency, and access mode

# %%
purpose_suff_access_ct = pd.crosstab(obs_df['TOUR_PURPOSE'], [obs_df['auto_suff'], obs_df['access_mode']], values=obs_df['linked_weight_scaled'], aggfunc=sum, margins=True)
purpose_suff_access_ct = add_percentage_to_crosstab(purpose_suff_access_ct)
purpose_suff_access_ct.fillna(0, inplace=True)
purpose_suff_access_ct.applymap(lambda x: round(x,2))
# Out:
# auto_suff                  0                          1                     \
# access_mode              KNR     PNR      Walk      KNR      PNR      Walk
# TOUR_PURPOSE
# Ind-Discretionary    596.850  78.570 18440.880  264.250   78.490  7007.160
# Ind-Maintenance      121.660  58.390 15510.080  272.910   96.920  4134.920
# Joint-Discretionary   69.800  10.750  1445.850   92.950    6.570   897.400
# Joint-Maintenance      0.000   0.000   828.850   15.330    5.640   440.080
# School                51.410   0.000  1809.070   44.480   31.780  3201.610
# University           473.480  77.240 15889.520  530.750  408.550 10793.300
# Work                1481.330 294.510 38136.800 2495.050 2076.400 39058.510
# Work sub-tour         86.350   0.000  1247.300   44.590   30.460  1323.370
# All                 2880.880 519.460 93308.350 3760.310 2734.810 66856.340
# Percent                1.060   0.190    34.260    1.380    1.000    24.550
#
# auto_suff                  2                            All Percent
# access_mode              KNR       PNR      Walk
# TOUR_PURPOSE
# Ind-Discretionary    456.930   265.800  7991.240  35180.160  12.920
# Ind-Maintenance      346.460   129.500  5171.940  25842.790   9.490
# Joint-Discretionary   51.740    63.180  1052.110   3690.360   1.350
# Joint-Maintenance      8.810     0.000   340.710   1639.410   0.600
# School               136.880    33.510  3626.990   8935.730   3.280
# University           489.590   991.610 11178.370  40832.400  14.990
# Work                2201.460 13642.270 52035.500 151421.820  55.600
# Work sub-tour        110.260    31.360  1939.160   4812.850   1.770
# All                 3802.140 15157.230 83336.020 272355.530 100.000
# Percent                1.400     5.570    30.600    100.000   0.000

# %% [markdown]
# ## Write coded output

# %%
obs_df.to_csv(os.path.join(output_path, 'processed_obs.csv'))
